# %%
import numpy as np
import matplotlib.pyplot as plt
M = 10000
K = 500
D_k = 10
K_d = int(K / D_k)
length = M * K_d

data = np.fromfile('output.bin', dtype=float, sep=',')
data = data[:length]

shape = (K_d, M)
data = np.reshape(data, shape)
print('data shape is', data.shape)
# Out:
# data shape is (50, 10000)

# %%
print(data.shape)
# Out:
# (50, 10000)

# %%
plt.plot(data[0, ])

# %%
plt.plot(data[5, ])

# %%
plt.plot(data[20, ])

# %%
plt.plot(data[40, ])
