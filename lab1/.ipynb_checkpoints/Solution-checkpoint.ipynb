# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
M = 5000
K = 100
length = K * M

data = np.fromfile('output.bin', dtype=float, sep = ',')
print(data.shape)
data = data[:length]

shape = (K, M)
data = np.reshape(data, shape)
print('data shape is', data.shape)
# Out:
# (500000,)
# data shape is (100, 5000)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
X = np.linspace(0, 1 - 1 / M, M)
T = np.linspace(0, 1 - 1 / K, K)
T, X = meshgrid(T, X)
ax.contour3D(T, X, data )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-2594919e3b70> in <module>
#       3 X = np.linspace(0, 1 - 1 / M, M)
#       4 T = np.linspace(0, 1 - 1 / K, K)
# ----> 5 ax.contour3D(X, T, data )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in contour(self, X, Y, Z, extend3d, stride, zdir, offset, *args, **kwargs)
#    2176         self.add_contour_set(cset, extend3d, stride, zdir, offset)
#    2177
# -> 2178         self.auto_scale_xyz(X, Y, Z, had_data)
#    2179         return cset
#    2180
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in auto_scale_xyz(self, X, Y, Z, had_data)
#     709         Y = np.reshape(Y, -1)
#     710         self.xy_dataLim.update_from_data_xy(
# --> 711             np.column_stack([X, Y]), not had_data)
#     712         if Z is not None:
#     713             Z = np.reshape(Z, -1)
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\shape_base.py in column_stack(tup)
#     654             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655         arrays.append(arr)
# --> 656     return _nx.concatenate(arrays, 1)
#     657
#     658
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 5000 and the array at index 1 has size 100

# %%
plt.plot(data[0, ])
plt.grid()

# %%
plt.plot(data[20, ])
plt.grid()

# %%
plt.plot(data[50, ])
plt.grid()

# %%
plt.plot(data[99, ])
plt.grid()
