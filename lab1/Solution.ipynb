# %%
import numpy as np
import matplotlib.pyplot as plt
M = 10000
K = 1000
D_k = 100
K_d = int(K / D_k)
length = M * K_d

data = np.fromfile('output.bin', dtype=float)
data = data[:length]

shape = (K_d, M)
data = np.reshape(data, shape)
print('data shape is', data.shape)
# Out:
# data shape is (10, 10000)

# %%
print(data.shape)
# Out:
# (10, 10000)

# %%
plt.plot(data[0, ])

# %%
plt.plot(data[1, ])

# %%
plt.plot(data[6, ])

# %%
plt.plot(data[9, ])
