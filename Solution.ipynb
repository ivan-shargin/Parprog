# %%
import numpy as np
import matplotlib.pyplot as plt
M = 1000
K = 500
D_k = 10
K_d =int(K / D_k)


length = (M + 1) * K_d 
data = np.genfromtxt("solution.txt", delimiter=',') 
data = data[0:length]
shape = (K_d, M + 1)
data = np.reshape(data, shape)
print(data.shape)
# Out:
# (50, 1001)

# %%
print(data[0, ])
# Out:
# [0. 2. 4. ... 0. 0. 0.]

# %%
plt.plot(data[0, ])

# %%
plt.plot(data[1, ])

# %%
plt.plot(data[6, ])

# %%
plt.plot(data[9, ])
